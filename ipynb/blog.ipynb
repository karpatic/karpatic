# %% [markdown]
# # My Blog
# > Written thoughts.
#
# - tab: 00_blog
# - keywords: ['Blogs']
# - hide_sitemap: true
# - hide_toc: true
# - hide_breadcrumbs: false
# - hide_transition: false
# - collapsable: h2
# - collapse: h3
# - collapse_sitemap: true

# %% [markdown]
# <script type="application/ld+json">
# {
#   "@context": "https://schema.org",
#   "@type": "WebPage",
#   "name": "Charles Karpati | Blog",
#   "url": "https://charleskarpati.com/blog",
#   "description": "Main navigation page for the Charles Karpati blog, featuring highlighted posts and a full index of all entries.",
#
#   "publisher": {
#     "@type": "Organization",
#     "name": "Charles Karpati",
#     "logo": {
#       "@type": "ImageObject",
#       "url": "https://avatars.githubusercontent.com/u/10605109?v=4"
#     }
#   },
#
#   "author": {
#     "@type": "Person",
#     "name": "Charles Karpati",
#     "url": "https://charleskarpati.com/"
#   },
#
#   "isPartOf": {
#     "@type": "Blog",
#     "name": "Charles Karpati Blog",
#     "url": "https://charleskarpati.com/blog"
#   },
#
#   "mainEntity": {
#     "@type": "Blog",
#     "name": "Charles Karpati Blog",
#     "url": "https://charleskarpati.com/blog",
#     "blogPost": [
#       {
#         "@type": "BlogPosting",
#         "headline": "About My Site",
#         "url": "https://charleskarpati.com/blog/aboutmysite"
#       },
#       {
#         "@type": "BlogPosting",
#         "headline": "Site Stats",
#         "url": "https://charleskarpati.com/blog/sitestats"
#       }
#     ]
#   }
# }
# </script>

# %% [markdown]
# <div id="shapecontainer">
#   <div id="shape">
#     <div class="blob">
#       <img src="https://avatars.githubusercontent.com/u/10605109?v=4" alt="placeholder" />
#     </div>
#   </div>
# </div>
#
# <style>
# /* layout */
# #shapecontainer{
#   display:flex;
#   justify-content:center;
#   align-items:center;
#   margin-bottom:60px;
# }
#
# /* outer animated gradient blob */
# #shape{
#   width:200px;
#   height:200px;
#   display:flex;
#   justify-content:center;
#   align-items:center;
#   background:linear-gradient(45deg,rgb(48,35,174)0%,rgb(255,0,153)100%);
#   border-radius:40%60%60%40%/40%55%45%60%;
#   box-shadow:rgba(255,255,255,.07)-10px 10px;
#   animation:outerBlob 5s infinite alternate ease-in-out;
# }
#
# /* inner animated blob image mask */
# .blob{
#   width:70%;
#   height:70%;
#   overflow:hidden;
#   animation:innerBlob 6s infinite alternate ease-in-out;
# }
#
# .blob img{
#   width:100%;
#   height:100%;
#   object-fit:cover;
#   animation:innerImg 6s infinite alternate ease-in-out;
# }
#
# /* outer shape morph */
# @keyframes outerBlob{
#   0%{transform:scale(1)translate(0,0);border-radius:40%60%60%40%/40%55%45%60%}
#   20%{transform:scale(1.2)translate(10px,10px);border-radius:45%55%42%58%/52%45%55%48%}
#   40%{transform:scale(1.1)translate(-10px,10px);border-radius:58%42%55%45%/45%62%38%55%}
#   60%{transform:scale(1.3)translate(1px,-10px);border-radius:42%58%48%52%/55%45%55%45%}
#   80%{transform:scale(1.1)translate(-10px,10px);border-radius:52%48%55%45%/48%55%45%52%}
#   100%{transform:scale(1)translate(0,0);border-radius:40%60%60%40%/40%55%45%60%}
# }
#
# /* inner blob mask */
# @keyframes innerBlob{
#   0%{border-radius:40% 60% 60% 40%/40%55%45%60%}
#   50%{border-radius:55%45%65%35%/50%60%40%50%}
#   100%{border-radius:40%60%60%40%/40%55%45%60%}
# }
#
# /* inner image morph */
# @keyframes innerImg{
#   0%{border-radius:40%60%60%40%/40%55%45%60%}
#   50%{border-radius:60%40%50%50%/45%60%40%55%}
#   100%{border-radius:40%60%60%40%/40%55%45%60%}
# }
# </style>

# %% [markdown]
# ## Featured

# %% [markdown]
# About [my site](./blog/aboutmysite.html)

# %% [markdown]
# ## All Entries

# %% [markdown]
# - About [my site](./blog/aboutmysite.html)
# - Site [stats](./blog/sitestats.html)
