# %% [markdown]
# # About My Site
# > Why and how I made my site.
#
# - keywords: ['3D','3D Printing', 'Crypto', 'metaverse', 'navigation']
# - hide_sitemap: true
# - hide_toc: true
# - hide_breadcrumbs: false
# - hide_transition: false
# - collapsable: h2
# - collapse: h3
# - collapse_sitemap: true

# %% [markdown]
# <script type="application/ld+json">
# {
#   "@context": "https://schema.org",
#   "@type": "WebPage",
#   "name": "Charles Karpati | About My Site",
#   "url": "https://charleskarpati.com/blog/aboutmysite",
#   "description": "Overview of the purpose, construction, and philosophy behind Charles Karpati’s personal website.",
#   "author": {
#     "@type": "Person",
#     "name": "Charles Karpati",
#     "url": "https://charleskarpati.com/"
#   },
#   "publisher": {
#     "@type": "Organization",
#     "name": "Charles Karpati",
#     "logo": {
#       "@type": "ImageObject",
#       "url": "https://avatars.githubusercontent.com/u/10605109?v=4"
#     }
#   },
#   "image": "https://avatars.githubusercontent.com/u/10605109?v=4",
#   "isPartOf": {
#     "@type": "Blog",
#     "name": "Charles Karpati Blog",
#     "url": "https://charleskarpati.com/blog"
#   }
# }
# </script>

# %% [markdown]
# ## What's in a Site?

# %% [markdown]
# This is my personal website. I use it, personally.
#
# It serves as the central hub for my pet projects and notes. I built it using a templating engine that takes python notebooks as input ^[This page was written in an IPYNB. It was converted by my static site generator with underlying use of the template engine. When visited, the page rehydrates using yaml extracted during it's creation.]{.dootdootdoo}.  I love to tinker, and so every part of this site was hand made.
#
# Through this process, I created an understated but packed website. Something incredibly light ^[ As of 2023, the average website sits at 2,200kbs in size. Mine's 15.], sophisticated and simple. You're looking at it!
#
# Apart from appearances, what does this look like?
#
# [Read on](./sitestats.html)
