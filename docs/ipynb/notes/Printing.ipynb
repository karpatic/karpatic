# %% [markdown]
# 0.25mm z distance.
# 75% xy distance.
# 3mm support spacing.
# 4 interface layers.
# 0.2mm interface layer spacing.
#  the standard 0.1 mm contact z distance should be 0.15 or 2 mm.
#
#
# https://www.3dhubs.com/knowledge-base/how-assemble-3d-printed-parts-threaded-fasteners/#self-tapping-screws
# https://www.3dhubs.com/knowledge-base/how-design-living-hinges-3d-printing/
# https://www.3dhubs.com/knowledge-base/how-assemble-3d-printed-parts-threaded-fasteners/
# https://www.font-generator.com/
# https://www.3dhubs.com/knowledge-base/how-design-snap-fit-joints-3d-printing/
# https://www.3dhubs.com/knowledge-base/enclosure-design-3d-printing-step-step-guide/
#
# https://www.thingiverse.com/search?q=Hamsa&type=things&sort=relevant
# https://www.thingiverse.com/thing:39898
# https://www.thingiverse.com/thing:451292
#
# Titebond H6838 - III Ultimate Wood Glue, 16 oz.
#
# https://www.thingiverse.com/thing:1613211
# https://www.thingiverse.com/davemakesstuff/designs
# https://www.thingiverse.com/thing:4645791
# https://www.thingiverse.com/thing:1201466
# https://www.thingiverse.com/thing:31581
# https://www.thingiverse.com/apps/customizer/run?thing_id=1046664
# grammmar
# --------------------------------------
#
# I want to create GIFs of 3D maps where the height is determined by real-world data about the place being shown. Object textures (+more), scene lighting, background and animations would be controllable aspects.
#
# algo sets certain parameters. mix of attributes randomly generated during minting process itself.
#
# - year - acs all - lighting - text on back - rotating - infoboxonclick
#
# Buy maps about the real world to sponsor a better CV world
# bundled items
# rarity and editions
# staggered listing and giveaways show transfers happening
# scale the price up
#
# - dynamic nfts
# - nft licenses
# - virtual worlds -> restricted access + discounts

# %% [markdown]
# https://hackaday.com/2022/11/24/electroplated-3d-printed-sword-shiny/

# %% [markdown]
# https://howto3dprint.net/how-to-create-a-3d-dog-in-selfcad-3d-modeling-software/?amp=1

# %% [markdown]
# 1.75 2.85 mm fillament
#
# diameter of nozzle tip .15 - 1.2mm, .4mm standard.
# heat stability is important
#
# brass - great for most. standard
# copper & (nicle platted copper) - brass made of copper and zinc. high heat capacity & Conductive. Softer & oxidizes so it gets plated.
# hardened steel - steel has high thermal capacity = good stability. lower thermal conductivity = low print speed.
# tungsten carbide - high temperature, standard stability, medium capacity
# ruby - resistant to scratching, brittle. bad conductor so it's used only on tip.
#
# thread size and correct length matters. too short and it jams. too long and it wont heat sufficiently.
# standardized sizes.

# %% [markdown]
# https://www.printables.com/model/260080-parametric-organizer-case/files
# https://www.printables.com/model/266907-app-to-create-keychains-amazing-stl-creator-4-free/comments
# https://www.thingiverse.com/thing:45576
# https://www.thingiverse.com/thing:46884
# https://www.printables.com/model/33019-sweeping-2-line-name-plate-text
# https://www.printables.com/model/62857-high-gardens-stackable-plant-vases-over-30-models-
# https://www.printables.com/model/153308-fully-customizable-pet-bottle-watering-spikeplant-/files
# https://3dp.rocks/lithophane/
# https://www.me.uk/puzzlebox/
# https://toms3d.org/2017/02/23/building-cheapest-possible-prusa-i3-mk2/
# https://powerbelt3d.com/product/powerbelt3d-zero-conveyor-belt-3d-printer-kit/
#
#
# (Website -(py,js)> development -(c++)> robots) jupyter
#
# audience - device type, location, carrier, time of day, language
# acquisition - #downloads, installs, users, version
# behavior - page views, button clicks, video views, crash analytics
# engagement - subscriptions, sales, retention, customer feedback
# impact -cpu utilization, memory usage, battery consuption, network data usage.
#
#
# https://observablehq.com/@jjimenez/using-different-data-formats-with-vega-lite
# from plotly.offline import iplot, init_notebook_mode
# init_notebook_mode(connected=True)

# %% [markdown]
# # Prints

# %% [markdown]
# ### Post Processing

# %% [markdown]
# - How To [Post Process](https://www.makerbot.com/professional/post-processing/)

# %% [markdown]
# # Repositories

# %% [markdown]
# https://all3dp.com/1/free-stl-files-3d-printer-models-3d-print-files-stl-download/

# %% [markdown]
# # Software

# %% [markdown]
# ### CAD

# %% [markdown]
# - Tinkercad

# %% [markdown]
# ### Scanners / Kinect

# %% [markdown]
# 3D scanning with a Kinect sensor - [Skanect](https://www.youtube.com/watch?v=H03kx514X2Y)
#
# How to clean up 3D scans with a Sculpting Tool

# %% [markdown]
# ### Sculpting

# %% [markdown]
# - How To [Sculpt](https://blog.prusaprinters.org/3d-sculpting-modeling-characters-and-organic-shapes_31705/)

# %% [markdown]
# - [SculptGL](https://stephaneginier.com/sculptgl/)

# %% [markdown]
# - [MeshMixer](https://alternativeto.net/software/meshmixer/?platform=linux)

# %% [markdown]
# https://all3dp.com/1/best-free-3d-modeling-software-for-beginners/

# %% [markdown]
# # Hardware

# %% [markdown]
# Welding Smarts
# Circuitry Basics
# Programming & Arduinos
# Working with Wood
# 3-D Printing
# Laser-cutting
# CNC Routing

# %% [markdown]
# # Misc

# %% [markdown]
# https://blog.cmgresearch.com/2020/06/05/self-organising-ws2811-leds.html
#
# https://www.thingiverse.com/thing:3505006
#
# https://www.amazon.com/Flexzion-Dehydrator-Food-Fruit-Dehydration/dp/B01J51JLCC
#
# https://www.prusaprinters.org/prints/32521-prusa-i3-mk3s-print-fan-shroud-sized-for-din557-sq
#
# https://www.prusaprinters.org/prints/18856-ships-wheel-knob-for-lcd
#
# https://learn.adafruit.com/dragon-lamp
#
# https://learn.adafruit.com/kingdom-key-keyblade
#
# https://learn.adafruit.com/prop-maker-light-wand
#
# https://learn.adafruit.com/neotrellis-soundboard
#
# https://www.matterhackers.com/articles/3d-print-hardware-from-mcmaster-carr
#
# https://www.mcmaster.com/
#
# https://nasa3d.arc.nasa.gov/models/printable
#
# https://www.prusaprinters.org/prints/32173-right-storage-box-with-an-angle
#
# screw measuring tool 3d print
#
# homekit32 esp32 case diy smarthome
#
# T-Rex Skeleton Base with space for 5x5mm LEDs and one ESP32
#
# https://github.com/sphawes/index
#
# https://www.thingiverse.com/thing:3917199
#
# https://www.thingiverse.com/thing:47591
#
# https://www.thingiverse.com/thing:4121683
#
# https://www.thingiverse.com/thing:2770916
#
# https://www.thingiverse.com/thing:1763518
#
# https://all3dp.com/2/3d-printer-belt-all-you-need-to-know/
#
# https://slic3r.org/
#
# https://all3dp.com/1/free-stl-files-3d-printer-models-3d-print-files-stl-download/
#
# https://all3dp.com/2/kinect-3d-scanner-easy-beginner-tutorial/
#
# https://www.thingiverse.com/thing:3570408

# %% [markdown]
# # CAD Programs 3d and PCB Notes

# %% [markdown]
# 0) Tinkercad - Made for 3d printing. Not a powerful PCB design tool. Used to play around with a virtual Arduino or build and simulate a virtual prototype of an analog circuit. As an added bonus, you can use its 3D modeling features to design the enclosure. This easy-to-use tool runs in your web browser. It uses Boolean Modeling to make objects using shapes as building blocks. Combine or subtract the basic shapes to create more complex designs. Really one of the more mature and fantastic 3D modeling software platforms that is robust and easy to approach, even for kids and beginners. isn’t quite in line with the team’s goals of keeping everything free and open. Although it was briefly in danger of going out of business, it was bought by AutoDesk who have made a lot of improvements. It is possible to program and simulate an Arduino in the same tool — which always strikes us as an odd juxtaposition. supports https://www.tinkercad.com/learn/codeblocks
#
#
# Blender and Sketchup are not CAD apps. They are polygonal modelers and as such cannot produce accurate and suitable models for CNC milling or laser cutting. True CAD software either use CSG (outdated) or boundary representation (B-Rep). All modern CAD software use B-Rep, and so does FreeCAD. BRL-CAD, works but its modeling method is constructive solid geometry (CSG), which is very limited, and this almost 30-year old program has a very ancient GUI.
#
# 1. Autodesk ( Eagles / Fusion 360 ) - EAGLE-Fusion integration - Although it’s not free to use (students can obtain a free license) anymore, Eagle is the defacto standard for many when it comes to circuit capture and PCB layout.  after being bought by Autodesk the software has been updated, and now works seamlessly alongside all of Autodesk’s other products such as Fusion360. 3D Renders of your PCB are now possible, and you can import the render into Fusion360, or Inventor to design the housing in which the PCB will reside. This is a handy feature for companies or individual who has already subscribed to other Autodesk products. Fusion 360 is remains free under the following conditions: If you are a student, you can try it free for up to 3 years. If you are a hobbyist or a small business (under $100,000), you can try it for free for 1 year after the initial 30-day trial expires. Fusion360 is a desktop 3D modeling program that uses cloud computing to assist with heavy computational loads like simulations. Beyond 3D modeling, it also includes workspaces for 3D sculpting (labeled Create Form in the software), sheet metal fabrication, rendering, animation of assemblies and operations, manufacturing with CNC machines and lathes, and simulations of static and nonlinear stress, thermal stress, structural buckling, and shape optimization. There’s a lot going on under the hood of Fusion360, so it’s intended for more experienced users, or at least those aspiring to become more experienced users.
#
#
# 2) EasyEDA is a free, zero- install, cloud-based EDA tool, designed to give electrical engineers, educators, engineering students and electronics hobbyists an Easier EDA Experience. It is easy to use circuit design, circuit simulator and PCB design that runs in your web browser. supports open source parts libraries. import PCB and Schematic files from popular CAD programs like Eagle. circuit simulator
#
# 3) FreeCad -  It turns out that early work on the project was done in the web-based TinkerCAD, which isn’t quite in line with the team’s goals of keeping everything free and open. They’d like some assistance in recreating the STLs in FreeCAD or OpenSCAD so they’re easier to modify down the road.
