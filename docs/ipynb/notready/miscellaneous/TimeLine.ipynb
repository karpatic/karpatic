# %% [markdown]
# Alphabet -> 1100BC
# Printer -> 1440AD
#
# edmond halley - 1656 - 1742
# Isac Newton - 1642 - 1723
# Gravitational F = G x m1 X m2 / D^2
# unit of force ='newtons' F = Mass * Acceleration
#
# James Watt 1835 - 1819
# Created Steam Engine. Created Horsepower
# Horsepwoer : #Kilos a horse can pull 1 meter within 1 sec
#
# James Joule - 1818 - 1889 -
# unit of work = 'joules' == W = Force x Length
#
# work done in 1 second = Power == p = work spent F x L / T
# unit of work done in 1 second == 'watt'
# If a certain amount of energy is spent in less time, it has a greater punch.
#
# William Gilbert - 1544 - 1603
# Came up with the word electricity
#
# charles coulomb - 1735 - 1806
#
#  chage is number of electrons
#
# electric charge = q = coulomb
# Coulombs law = K(e) x q1 x q2 / d^2
# Very similar to gravity. He has a cool method of prooving his methods
#
# Andre-Marie Ampere - 1775 - 1836
# Magnetic Force - imposed when passing electricity between two adjacent wires
# electric currents in the same direction attract eachother
# Unit of current - amperes/ amps == I
#
# I = q / t
# The electric charge create the magnetic force
# 1 coulomb is defined sa the amount of charge that one amp of current can carry every second --> 1C = 1A x 1s
#
# Alessandro Giuseppe Volta ->1745 - 1827
# first battery -> voltaic pile
# total energy does not effect electric current
# electric current is affected by the available energy per unit charge
# Volt = joules per coulomb == voltage == electric potential
#
#
# voltage = work(energy)/q(charge)
# I(currnt) = q(charge)/ time(second)
# Conductive current runs from high voltage to low

# %% [markdown]
# Need to know :
#
# binomial theorem (or binomial expansion) describes the algebraic expansion of powers of a
# binomial
# Series
# -- an infinite ordered set of terms combined together by the addition operator.
# Series expansion
# -- a representation of a function as a sum of powers of a value
# -- The value may be found within the function itself OR could be another random function/value
# entirely
# -- Example === 1/(1-x) == 1 + x + x^2 + x ^ 3
# Taylor Series
# -- A Taylor series is a series expansion of a function about a point
# Colin Maclaurin
# -- If a=0, the expansion is known as a Maclaurin series.
#
# Timelines :
# - https://en.wikipedia.org/wiki/Timeline_of_machine_learning
# - https://en.wikipedia.org/wiki/Timeline_of_artificial_intelligence#2010s
# - http://www.futureforall.org/latest-technology-breakthroughs.html
# - http://www.futuretimeline.net/
#
# Semantics of Social and Information Connections.
# Web 4.0 - intelligent personal agents
# Web 4.0 - Distributed search
# Web 3.0 - Plugins, Widgets &amp; Mashups
# Web 3.0 - Semantic Search &amp; Databases (sparql, owl)
# Web 2.0 - Office 2.0 &amp; collaboration
# Web 2.0 - Web Blogs * Social Media Sharing
# Web 2.0 - Directory Portals, wikis (Ajax, Rss, RDF, OpenId, Flash, P2P, Javsacript)
# Web 1.0 - Websites (HTTP/ HTML/ SOAP)
# PC Era - File Servers &amp; Databases (SQL, Mac, Windows)
# Pre PC - File Systems ( FTP, IRC, Email)
#
# Timeline :
# 11thish century - odessyus theseus jason and the argonauts
# tabula rasa! I think there for I am! To be or not to Be?! The creator grows what he seeds!
# product of your enviornment but create your own reality
# the singularit will be the single most holonic convergence since mitosis
# If someone controls what you are fed. You are a product.
# Figurate Numbers and Sums of Numerical Powers: Fermat, Pascal, Bernoulli :
# https://www.maa.org/press/periodicals/convergence/figurate-numbers-and-sums-of-numerical-
# powers-fermat-pascal-bernoulli
# Bernoullis Number, Distribution, Binomial Distribution
# The Euler numbers are a sequence of integers intimately connected with the Bernoulli numbers.
# Comparing the asymptotic expansions of the Bernoulli and the Euler numbers shows that the
# Euler numbers E2n are in magnitude larger than the Bernoulli numbers. In consequence:
# This asymptotic equation reveals that π lies in the common root of both the Bernoulli and the
# Euler numbers. In fact π could be computed from these rational approximations.
# draco - first legislator
# 528 - buddahs enlightenment
# 501- confucius
# Seven Sages of Greece (638 BC–558 BC)
# Zoroaster (1000 or c.628 - c.551 BC) - Zoroastrianism.
# Thales (c. 624 – c. 546 BC) - Father of philosophy
# Pythagoras (572–497) - Student of Thales - koinà tà phílōn
# Permenides (515-430 BC) - change perceived with our senses is deceptive. There is a pure
# perfect and eternal being behind nature.
# Zeno (490–430 BC) - Zeno was 25 years younger and the pupil of Parmenides - Dialectecs -
# Proof by Contradiction. Logical Obserdity.
# Heraclitus (Ηράκλειτος) (c. 544 - 483 BC) - ever-present change as being the fundamental
# essence of the universe. Opposite of Permenides.
# Democritus (c.460 — c.370 BC) - Philosophy of Atoms.
# Euclid ( ~450BC - ~350BC) - founder of geometry
# Diogenes - 404 BC - 323 BC - He was the first Cynic, met alexander
# Epicurus (341–270 BC) - Studied Diogenes and adopted Euclid
# Platonic Academy in 387 BC
# Aristotle (384–322 BC) - Platos Student introduced empiricism - Father of Western Philosophy
# Zeno of Citium ( 334 – c. 262 BC) - Stoicism
# Archimedes (287–212)
# Spinoza (1632-1677)
# Franciscus Vieta (1540–1591-1603) - Symbolic Notation
# John Wallis (1616-1655-1703) - studied sums of powers
# Johann Faulhaber (1580-1631-1635)
# - developed explicit formulas for the sums of powers of integers sums up to p=17
# Pierre de Fermat (1601-1636-1665)
# - Figured out how to determine min, max and tangents for f(x)
# - Using Tangents, evaluated the integral of general power functions.
# - Was able to apply this work to Geometric Series (predecessor of calculus).
# - Working with Pascal, 1654, Established the foundation probability theory
# Descartes - (1596-1637-1650)
# - Built off Fermats 1636 work, Established Cartesian geometry because of it.
# - I think therefor i am - Championed for the Scientific Method
# - father of analytical geometry, the bridge between algebra and geometry,
# - analytical geometry, is used in the discovery of infinitesimal calculus and analysis.
# Blaise Pascal - (1623 - 1654 - 1662)
# - 1653, Pascals Triangle, tabular presentation for binomial coefficients
# - 1654, Pascals Identity, Proved Power Notation for all numbers
# - Worked with Fermat in 1654, Established the foundation probability theory
# - Created mechanical calculator
# Isaac Newton - (1643 - 1687 - 1727)
# - wrote that his own early ideas about calculus came directly from &quot;Fermat&#39;s way of drawing
# tangents.&quot;
# Gottfried Leibniz - (1646 - 1716)
# - Depended on work of Pascal &amp; Fermat
# - Differential &amp; Integral Calculus + Integral notation
# - Improved + Mass Produced Mechanical Calculators
# - Improved Binary Number System
# - Logic &amp; Analytic Philosophy
# Jakob Bernoulli (1654–1713-1705)
# - Early adopter of Leibniz, Coined the term &#39;integral&#39;
# - landmark work in combinatorics and founder of mathematical probability who...
# - Solidly Connects probability theory and sums of power. For example he...
# - Improved Pascals Identity for easy use with all sorts of polynomial forumulas...
# - I.E, Bernoulli&#39;s formula : For the sum of powers of numbers
# - used in Eulers Euler-MacLaurin Sumation to conveniently express Convergence
# - Discovered e in 1683 studying Compound Interest,
# - Founded the study of Law of Large Numbers, 1689, using Seperation of Variables
# Euler - (1707-1748/1755-1783)
# - Came up with a lot of Notation like f(x), Sigma, e, pi, writting trig functions,
# - Coined the term e -&gt; 2.718 irrational constant -&gt; eulers number -&gt; magical number
# - Added to Infintismal Calculus
# - Added to Graph Theory, Topology
# - Sigma Notation
# - applied Bernoulli numbers, Fourier Series, e (taylor series), leibniz (calculus notation) +
# newton (calculus methods)
# - fundamental theorems of addition and multiplication of probabilities along with several
# problems applying the Bernoulli process
# Thomas Bayes (1701–1763-1761)
# - describes the probability of an event, based on prior knowledge of conditions that might be
# related to the even
# - P(A|B) = P(B|A)xP(A)/P(B)
# Pierre Simon Laplace’s (1749-1812-1827)
# - Laplace presented the definition of probability
# Gauß (1777–1796-1855)
# - The Normal Distribution : Showed how probability could be represented by a bell-shaped or
# “normal” curve
# - Line of Best fit : minimizing error between points and a line
# Bernhard Riemann - ( 1826, 1868, 1866)
# - first rigorous definition of the integral of a function on an interval.
# John Von Neumann - 1944 - Game Theory
# John Nash - 1950 - Nash Equilibrium
