# %% [markdown]
# Spatial data formats (drag drop):
# postgresql, oracle, csv, mapinfo, kml, gml, shapefile, filedgb, geojson, cartodb

# %% [markdown]
# https://geodacenter.github.io/
#
# Multi Layer Support
#
# connect to carto
#
# explore statistical results through linked maps and charts
# (multiple graphics depicting same thing)
#
# analyzing spatial and temporal patterns accross linked views (group variables together vs ungrouped variables)
#
# compare avg across space an d time
#
# group obs mean sd
#
# detect relationships in multivariate space (scatterplot matrix with bar charts running down middle)
#
# statistically ignificant spatial clusters ( spatial autocorrelation, local moran cluster map, local G/G*, local join count statistics for categorical data.
#
# spatial clustering - skater, redcap, maxp k means kmedians kmedioids, spectral clustering
#
# detect if changes over time are spatially clustered
#
# global/local differential morans I test to find out if a variables change over time in a given location is statistically related to that of its neighbors. (lisa cluster map)
#
# test if multiple variables are clustered in space (moral correlation)
#
# map patterns of non spatial cluster stats (pca, kmeans, hierarchical clustering, multi dimensional scaling))
#
# (spatial corerelation threshold) correlogram determin distance thresholds when the values of neighboring pairs are no longer correlated
#
# breakpoint edit/customization
