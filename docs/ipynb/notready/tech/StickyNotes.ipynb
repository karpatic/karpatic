# %% [markdown]
# Lit pigment

# %% [markdown]
# kids have a survivability rate of 99.98%
# 99% among unvaccinated
# 78% are overweight
# 75% are 65 years or older

# %% [markdown]
# // Collections / Wearable middleware
# // Also handles some legacy case.
# // un-refreshed opensea collection pages use the collections/:x:/y endpoint on a button to link to our collections page.
# // this middleware redirects those requests to the proper url. otherwise the collections page may break??
# // Otherwise: That endpoint has changed in it's use, making legacy support not possible.
# const identifyCollectionParams = async (req: Request, res: Response, next: NextFunction) => {

# %%
ethereum-listener.ts 

import { ethers } from 'ethers'
import { landworksRentingExtensioncontract, parcelContract } from '../lib/utils'
import Parcel from '../parcel'
import ParcelUserRight from '../parcel-user-right'

export const listenToContracts = () => {
  parcelContract.on('Transfer', async (from: string, to: string, id: ethers.BigNumber) => {
    const tokenId = id.toNumber()
    const parcel = await Parcel.load(tokenId)
    if (!parcel) {
      return
    }
    if (!ethers.utils.isAddress(to)) {
      return
    }
    parcel.owner = to
    if (!parcel.minted) {
      // This parcel has recently been minted! Remember to make it visible the next time it's saved.
      // (This, and similar logic in AbstractParcel.queryContract(), is now the *only* way in which the minted and
      // visible properties of a parcel interact.)
      parcel._justGotMinted = true
    }
    parcel.minted = true
    parcel.save()
  })

  // TODO: uncomment on 1st of may
  landworksRentingExtensioncontract.on('ConsumerChanged', async (owner: string, consumer: string, id: ethers.BigNumber) => {
    const tokenId = id.toNumber()
    // if (owner.toLowerCase() !== LANDWORKS.toLowerCase()) {
    //   return
    // }
    // on new consumer evict the current Renter
    ParcelUserRight.evictRenter(tokenId)
    if (consumer !== ethers.constants.AddressZero) {
      // new consumer is not the address Zero, it's a new renter
      ParcelUserRight.createRenter(tokenId, consumer)
      ParcelUserRight.deleteAllButRenter(tokenId)
    }
  })
}

# %% [markdown]
# Forest Arc
# Souls of nature
# Stageverse
# Decentral Games
# Vyworlds
# Upland
# CEEK VR
# Pax.world
# Spatial
# Bloktopia
#
# Cryptovoxels
# Hyperfy.io
# Substrata
# The Sandbox
# Decentraland
# SomniumSpace,
# wordwide webb
# NFT World
# Mona
# otherdeed
# Illuvium
# Axie Infinity
# GTA5/ Fortnite
# Meta Horizon/ VRChat
# Minecraft/ Roblox

# %% [markdown]
# twee - excessively or affectedly quaint, pretty, or sentimental.
# mawkish - sentimental in a feeble or sickly way.

# %% [markdown]
# fixer upper book

# %%
Chesterton's Fence

# %% [markdown]
# When it outgrows the single EC2 instance, I'll likely start building some distributed thingy to spread the load and do some HA things (sounds like fun). Probably just a load balancer and 2-3 instances with a rqlite backend instead of SQLite, nothing too fancy.
#
# It's quite cheap to run. It's just one small EC2 instance, and it's usually idling around a load average of 0.1 (though right now it's at 1, hehe). It costs me about $24/month. The Apple developer license costs $100 per year, so it's ~$400/year. As of recently, that's entirely covered by donations.
#
# I think switching to a cheaper cloud service like Linode or Hetzner would be the way to go.
#
# A free Oracle Cloud VM or $5 Digital Ocean droplet would be the way I go.
#
# A free Oracle Cloud VM still costs you your soul, in perpetuity
#
#
#
#
#
# When I was making my IoT washing machine sensor, I used Blynk.io to push notifications to my phone but of course that service became
# commercialised and is no longer free. I could not find any nice easy to use alternative except for Telegram which is what I use now. This service looks exactly like what I would need and I appreciate the promise to keep it open source.
#
#
#
#
# https://pushover.net/ Has existed for several years. It works great for me.
#
# I've used pushover for years as well. I wish they would charge me $5/y instead of a $5/lifetime.
#
# I set up Tasker on my phone such that when a specific low-priority (no visible/audible alert) message from pushover, containing only a hash key, is received it picks it up and does an HTTPS request to my self-hosted server to retrieve the actual notification text.
#
#
#
# Another alternative: you can send notifications to your phone through text messages. Text messages are compatible with email, usually in the form of <number>@<special-provider-url>.
#
#
# https://www.verizon.com/about/news/vzw/2013/06/computer-to-phone-text-messaging
#
# https://gotify.net/

# %% [markdown]
# # VR

# %% [markdown]
# https://www.amazon.com/s?k=vr+battery+pack&i=electronics&ref=nb_sb_noss_2
# https://www.amazon.com/Silicone-Anti-Sweat-Washable-Anti-Leakage-Blocking/dp/B08MFF9NLM/ref=sr_1_4?dchild=1&keywords=oculus+quest+sanitary&qid=1623697433&sr=8-4
#
# https://www.unrealengine.com/en-US/digital-humans
# https://www.unrealengine.com/en-US/blog/download-our-new-blender-addons
#
# v29
# - quest built in mic and - cast to recording w mic
# - mixed realy - live overlay
#
#
#
# VR optimal performance:
# Within Virtual Desktop Settings Pane (Oculus): set medium graphics. 32-55-75mbps @ 72-80fps w/o video buffering
# Within Windows: Right Click Desktop -> NIVIDIA Control Panel -> Manage 3D Settings -> Low Latency Mode -> Ultra
# Within Virtual Desktop Streamer (Computer): Set Preferred Codec to H.264 w/o auto adjusted bit-rate.
# sliced encoding ON (every frame gets individually encoded for less latency)
# extra latency OFF (less stutter more latency)
# video buffering OFF ( reduce stutters more latency)
#
# VR Beat Saber
# https://developer.oculus.com/manage/organizations/116844850459343/
# https://developer.oculus.com/get-started/
# https://bmbf.dev/stable
# https://bsaber.com/
#
# VR UNITY
# https://assetstore.unity.com/
# https://docs.vrchat.com/docs/creating-your-first-avatar
# rig 3d character, avatar or model for vrchat
# https://vroid.com/ studio
# vrstudio
# https://www.vseeface.icu/
# https://vrchat.com/home/user/usr_27bfcb0c-ab92-4e30-96d6-7196dd432730
# https://id.unity.com/en/account/edit
# blender - unity - quest -vrchat
# https://github.com/madjin/awesome-vrchat
# VR 3D
# https://stemkoski.github.io/Three.js/index.html
# https://www.freecodecamp.org/news/three-js-tutorial/
# view-source:https://stemkoski.github.io/Three.js/models/android-animations.js
# https://medium.com/swlh/building-a-3d-interactive-with-react-and-threejs-70dfd212bf67

# %% [markdown]
# # Blender

# %% [markdown]
# Blender
#
#
# https://maketafi.com/tafi-vr-chat-edition
#
# https://readyplayer.me/vrchat
# https://docs.godotengine.org/en/stable/getting_started/workflow/export/exporting_for_web.html#
# https://bazar.preciousplastic.com/
# https://www.youtube.com/watch?v=Vvo0LfjcLNU
#
# https://www.sprayon.com/product/lu211-food-grade-dry-silicone-lubricant/
#
# https://all3dp.com/2/blender-uv-mapping-simply-explained
# https://all3dp.com/2/blender-lighting-simply-explained/
# https://all3dp.com/2/blender-how-to-move-the-camera/
# https://all3dp.com/2/blender-how-to-merge-objects/
# https://www.youtube.com/watch?v=oA_ldIuYRmk
# https://www.youtube.com/watch?app=desktop&v=HlRMxmakFzg
# https://www.youtube.com/watch?v=VVD8gsjcA4g
# https://www.youtube.com/watch?v=SBYb1YmaOMY
# https://www.youtube.com/watch?v=f2pTkW-1JkE
# https://www.textures.com/
# https://3dtextures.me/
# https://www.archinspirations.com/
# https://freepbr.com/
#
# aa to select all
# alt+H to unhide everything
# tab goes to edit mode
# alt click vertex -> ctrl+E-> "clear seam"
# https://webflow.com/dashboard/sites/new?ref=create-site
# https://motionden.com/pricing
# velosofy video templates blender templates, unity asset store
# space mouse
# drawing tablet
#
# voxel architects - meeting + video
# meta archs - lost
#
# https://gist.github.com/moritree/13fa89e931a72c57dd2b9a3d0ef25610
#
# edit mode - ctrl a + u = unwrap - smart uv unwrap
# texture painting panel at top
#
# character turnaround
#
# f = force
# shift f = radius
# shift = smooth
# ctrl = op
#
# n = transformation pane toggle.
# shift + A = "add menu"
#
# red = x axis & green = y axis
# g/r/s = move/Rotate/scale
# x/y/z = move on x/y/z axis.
# alt +g/r/s = return to defualt
# ctrl + a + "apply all transform" =  sets the default to current orientations.
# 1 = front
# 3 = right
# 7 = top
# ctrl = opposites
# 5 = reset perspective
# dot = zoom on item
# forward slash =  isolated 'local' view
#
# blender vfx - 2d animation - general - sculpting - video editing
# https://docs.blender.org/manual/en/2.92/
#
# scene property panel sets unit measurements.
#
# spiralize dual contour
#
# isomorphism
# intransigence

# %% [markdown]
# # Woodworking

# %% [markdown]
# oils, enamels, lacquers, and acrylics
# stick to acrylic
# airbrush, a brush, or canned spray paint
# t. While a brush is cheaper compared to the other options, it can be tough to accomplish an even coat of paint, with noticeable blobs in some spots and the underlying color appearing in others. An airbrush, on the other hand, is costly and typically has a steep learning curve.
#
# Pre-sanding
# Craft knife (Exacto knife)
# Sandpaper
# Tweezers
# Toothbrush
# Pliers
#
# Sanding
# Begin with 120-grit sandpaper and work your way up. Use circular motions.
#
# Priming turns your 3D print into a professional product and makes the painting process effortless. Go for a primer that is compatible with your plastic. We prefer using a spray-on
# use highest grade fill
#
# then wood filler
# or spot putty
#
# Painters tape
#
# Add coats: Mask the relevant areas to preserve details and add the topcoats. Think of topcoats as layers over the previous coats. The first and second coats will show more if the topcoat is thinner
#
# Finish with a clear coat: This is meant to “seal” the painted model, protecting the paint surface and achieving the desired sheen. Apply the clear coat in one or two thin and even layers
#
# you can still polish it further with wax or a fine polishing compound if you want a super glossy finish.
#
# Let the paint dry overnight and clean the part the next day using a tack cloth.
#
# varnish will protect it at the end
#
# https://www.masterclass.com/articles/types-of-spray-paints-explained#10-types-of-spray-paints
#
# https://www.masterclass.com/articles/what-is-satin-fabric-a-guide-to-the-types-characteristics-and-uses-for-satin#quiz-0
#
# https://www.masterclass.com/articles/what-is-twill-fabric-definition-and-characteristics-of-the-popular-twill-weave#what-is-twill-used-for
#
# https://www.masterclass.com/articles/different-types-of-wall-paint-and-finishes#what-to-consider-when-choosing-a-paint-finish
#
# Technically speaking, gloss and sheen are two aspects of the same thing: The amount of light reflected off a painted surface independent of its color. But to the eye, they are very different: Gloss is shiny and crisp while sheen looks softer and has more depth and luster.
#
# https://www.amazon.com/dp/B0000WS014?tag=all3dp0c-20
#
# https://www.amazon.com/dp/B078WLZL6Q?tag=all3dp0c-20
#
# - stepper bits
# - shop vaccum
# - dremmel
# - https://www.amazon.com/Weldon-Applicator-Bottle-Pint-10308/dp/B00TCUJ7A8/ref=sr_1_3?dchild=1&keywords=plexiglass+glue&qid=1627686840&sr=8-3
#
# https://www.amazon.com/s?k=Luer+Lock+bottle&ref=nb_sb_noss_2
#
# https://www.eplastics.com/lighting-diffusers/cracked-ice
#
# https://www.harborfreight.com/air-tools-compressors/air-tools/blasting-cleaning.html?utm_source=google&utm_medium=cpc&utm_campaign=12187003912&campaignid=12187003912&utm_content=122725685411&adsetid=122725685411&product=&store=&gclid=CjwKCAjwxo6IBhBKEiwAXSYBs04Xy7xMBACQTZvxMC3hUXc0c4oyLN3eCdTe_eaD5JesCUquJS8QARoC9RgQAvD_BwE

# %% [markdown]
# # Misc

# %%
https://en.wikipedia.org/wiki/Pope_Leo_X
 Misc Concepts
Evo of reality -> information is evolving towards greater states of complexity :
heuristics ignoree the asymetry  : P(A|B) != P(B|A)
Humanity does not contain a beginning middle & ending
Continued growth is unsustainable for humanity.
Infinite game - not win reality but keep it going
Human value is how to keep machine going
How can we trust our models when all our assumptions are based on heuristics
limbic (primitive) resonance express the cybernetic collective.
cortex (foreward) - in service of limbic system.
bleached emotions
standing at the peak of one local topology i look to other local maxima

http://wiki.c2.com/?GoodStyle
~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Things that give me the funnies
~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
chekovs gun
greek alphabet, phonetic alphabet, hungarian runes
kernal popcorn, general merryment, private chuckle
"In Case of <Strange Disaster> Do This:
    (" banana suit peanut butter leap through window, ect), snippets.
Unit conversions
writing conventions
Is mickey mouse a cat or a dog?
Series of small fires
let me dry my hands in this little thing right here
foghorn leghorn 
~~~~~~Andre’s tatoos~~~~~~
Vegvisir, Aegishjalmur, Ginfaxi, Ginnit, Finland

~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Quotes Moments 
~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~